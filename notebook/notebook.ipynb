# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### | Reading The Data Set

# %%
DATAPATH = os.path.join(os.getcwd(), "../", "Data/energydata_complete.csv")

# %%
df = pd.read_csv(DATAPATH)
